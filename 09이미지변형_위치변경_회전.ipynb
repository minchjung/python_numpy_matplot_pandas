# %% [markdown]
# <a href="https://colab.research.google.com/github/minchjung/python_numpy_matplot_pandas/blob/main/09%EC%9D%B4%EB%AF%B8%EC%A7%80%EB%B3%80%ED%98%95_%EC%9C%84%EC%B9%98%EB%B3%80%EA%B2%BD_%ED%9A%8C%EC%A0%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ab5d79d-f4d8-44e2-9eac-7405056c8bf5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ab5d79d-f4d8-44e2-9eac-7405056c8bf5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3.jpg to 3.jpg

# %%
import cv2
import matplotlib.pyplot as plt
# image np객체 생성 
image =cv2.imread('3.jpg')
# image np객체 행렬 BGR정보 중 행렬 정보 
h,w = image.shape[:2]

# %%
import numpy as np

# 이미치 위치 변경 
# warpAffine(이미지 넘파이 객체, 변환행렬m, (반환행렬 사이즈 w, h))
# 위치 조정 2x3 m = [ [1,0,가로늘릴크기],[ 0,1, 세로 늘릴크기]  ]
m1 =np.float32([[1,0,50],[0,1,10]])
pos = cv2.warpAffine(image,m1,(w,h))
plt.imshow(cv2.cvtColor(rot, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 이미지 회전 
# warpAffine(이미지 넘파이 객체, 변환행렬M, (반환행렬 사이즈w, h))
# 회전변환용 M값 생성
# getRotationMatrix2D ( (회전축좌표x,y), 회전각도 , 스케일  )
m = cv2.getRotationMatrix2D((w/2,h/2),-90,1) 
rot = cv2.warpAffine(image,m,(w,h))

plt.imshow(cv2.cvtColor(rot, cv2.COLOR_BGR2RGB))
plt.show()
