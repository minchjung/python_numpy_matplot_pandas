# %% [markdown]
# <a href="https://colab.research.google.com/github/minchjung/python_numpy_matplot_pandas/blob/main/09%EC%9D%B4%EB%AF%B8%EC%A7%80%EB%B3%80%ED%98%95_%EB%B3%B4%EA%B0%84%EB%B2%95.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2e2f2ad8-3c50-469c-a8fa-16dee3a9a528" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e2f2ad8-3c50-469c-a8fa-16dee3a9a528">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3.jpg to 3.jpg

# %%
import cv2
import matplotlib.pyplot as plt
# 원본 출력 
image = cv2.imread('3.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 2배확장 , interpolartion 인자 값으로 cv2.INTER_CUBIC 
expand = cv2.resize(image, None, fx=2.0, fy=2.0, interpolation = cv2.INTER_CUBIC)
plt.imshow(cv2.cvtColor(expand, cv2.COLOR_BGR2RGB))
plt.show()

# %%
# 0.8배 축소 , interpolartion 인자 값으로 cv2.INTER_AREA 
shrink = cv2.resize(image,None, fx=0.8, fy=0.8, interpolation=cv2.INTER_AREA)
plt.imshow(cv2.cvtColor(shrink, cv2.COLOR_BGR2RGB))
plt.show()
